# %% [markdown]
# ## Mount the Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Chnage Current Directory to Learning-to-See-in-Dark

# %%
# %cd /content/drive/MyDrive/NNFL_Paper/Learning-to-See-in-the-Dark
# Out:
# /content/drive/MyDrive/NNFL_Paper/Learning-to-See-in-the-Dark

# %%
  # !ls -l
# Out:
# total 92
# drwx------ 4 root root  4096 Nov 24 14:23 checkpoint
# drwx------ 2 root root  4096 Nov 24 14:23 dataset
# -rw------- 1 root root  1415 Nov 24 14:20 download_models.py
# -rw------- 1 root root 64442 Nov 25 12:59 NNFL_Driver_Colab.ipynb
# drwx------ 3 root root  4096 Nov 25 09:49 result_Sony
# -rw------- 1 root root  6551 Nov 25 06:13 test_Sony.py
# -rw------- 1 root root  8490 Nov 25 10:16 train_Sony.py

# %% [markdown]
# ## Install Requerments

# %%
# !pip install tensorflow==1.15
# Out:
# ...
#      |████████████████████████████████| 412.3MB 41kB/s
# ...
#      |████████████████████████████████| 51kB 6.1MB/s
# ...
#      |████████████████████████████████| 512kB 44.2MB/s
# ...
#      |████████████████████████████████| 3.8MB 41.6MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=b1d57313c6dabeb799d58188b7eaa6af77bd0d440c7252daf1e7817eed0dd4ab
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorboard 2.3.0
# ...

# %%
# !pip install rawpy
# Out:
# ...
#      |████████████████████████████████| 1.7MB 6.1MB/s
# ...

# %%
# !pip install scipy==1.2.0
# Out:
# ...
#      |████████████████████████████████| 26.6MB 120kB/s
# ...
# ERROR: umap-learn 0.4.6 has requirement scipy>=1.3.1, but you'll have scipy 1.2.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %% [markdown]
# ## Run this to train the Model
#
# #### 1. Don't put No of images more then 100 the colab will collapse
# #### 2. Put No.of Epoch Accordingly
# #### 3. Save Frequency can be anything but less then No. of Epoch.

# %%
# !python train_Sony.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 1401 2 Loss=0.022 Time=0.070
# 1401 3 Loss=0.022 Time=0.071
# 1401 4 Loss=0.022 Time=0.091
# 1401 5 Loss=0.022 Time=0.076
# 1401 6 Loss=0.021 Time=0.094
# 1401 7 Loss=0.021 Time=0.093
# 1401 8 Loss=0.022 Time=0.076
# 1401 9 Loss=0.021 Time=0.093
# 1401 10 Loss=0.021 Time=0.091
# 1401 11 Loss=0.021 Time=0.069
# 1401 12 Loss=0.021 Time=0.076
# 1401 13 Loss=0.021 Time=0.078
# 1401 14 Loss=0.021 Time=0.076
# 1401 15 Loss=0.021 Time=0.093
# 1401 16 Loss=0.021 Time=0.093
# 1401 17 Loss=0.021 Time=0.093
# 1401 18 Loss=0.021 Time=0.093
# 1401 19 Loss=0.021 Time=0.092
# 1401 20 Loss=0.021 Time=0.070
# 1401 21 Loss=0.021 Time=0.095
# 1401 22 Loss=0.021 Time=0.070
# 1401 23 Loss=0.021 Time=0.075
# 1401 24 Loss=0.021 Time=0.089
# 1401 25 Loss=0.021 Time=0.089
# 1401 26 Loss=0.021 Time=0.093
# 1401 27 Loss=0.021 Time=0.070
# 1401 28 Loss=0.021 Time=0.091
# 1401 29 Loss=0.021 Time=0.070
# 1401 30 Loss=0.021 Time=0.095
# ...

# %% [markdown]
# ## Run this to test the Model

# %%
# !python test_Sony.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Enter #Test images: 10
# WARNING:tensorflow:From test_Sony.py:97: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-11-25 17:35:40.540463: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-11-25 17:35:40.559509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
